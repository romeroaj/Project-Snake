# %%
# Dependencies
import requests
from config import api_key

# %%
# Build query URL and request your results in Celsius
url = 'https://api.globalwinescore.com/globalwinescores/latest/?'
url2 = '&limit=10'

query_url = f'{url}{url2}'
# Get weather data
response = requests.get(query_url, headers={'Authorization' : f'Token {api_key}'})

# %%
print(query_url)
# Out:
# https://api.globalwinescore.com/globalwinescores/latest/?&limit=10

# %%
data = response.json()
data
# Out:
# {'count': 30956,
#  'next': 'https://api.globalwinescore.com/globalwinescores/latest/?limit=10&offset=10',
#  'previous': None,
#  'results': [{'wine': 'Marchesi Antinori, Badia a Passignano, Chianti Classico Gran Selezione',
#    'wine_id': 147377,
#    'wine_slug': 'marchesi-antinori-badia-a-passignano-chianti-classico-gran-selezione',
#    'appellation': 'Chianti Classico Gran Selezione',
#    'appellation_slug': 'chianti-classico-gran-selezione',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Tuscany'],
#    'country': 'Italy',
#    'classification': None,
#    'vintage': '2015',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 93.59,
#    'confidence_index': 'A+',
#    'journalist_count': 5,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'E. Guigal, Chateauneuf Du Pape',
#    'wine_id': 68461,
#    'wine_slug': 'e-guigal-chateauneuf-du-pape',
#    'appellation': 'Chateauneuf Du Pape',
#    'appellation_slug': 'chateauneuf-du-pape',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Rhone'],
#    'country': 'France',
#    'classification': None,
#    'vintage': '2015',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 90.68,
#    'confidence_index': 'B+',
#    'journalist_count': 5,
#    'lwin': 1113130,
#    'lwin_11': 11131302015},
#   {'wine': 'Chateau Montlabert, Saint Emilion Grand Cru',
#    'wine_id': 39471,
#    'wine_slug': 'chateau-montlabert-saint-emilion-grand-cru',
#    'appellation': 'Saint Emilion Grand Cru',
#    'appellation_slug': 'saint-emilion-grand-cru',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': None,
#    'vintage': '2016',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 89.85,
#    'confidence_index': 'B+',
#    'journalist_count': 9,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'Chateau Larose Trintaudon, Haut Medoc',
#    'wine_id': 38120,
#    'wine_slug': 'chateau-larose-trintaudon-haut-medoc',
#    'appellation': 'Haut Medoc',
#    'appellation_slug': 'haut-medoc',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': 'Cru Bourgeois',
#    'vintage': '2016',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 89.09,
#    'confidence_index': 'B',
#    'journalist_count': 7,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'Vignobles Lannoye, Chateau Lanbersac, Puisseguin Saint Emilion',
#    'wine_id': 140096,
#    'wine_slug': 'vignobles-lannoye-chateau-lanbersac-puisseguin-saint-emilion',
#    'appellation': 'Puisseguin Saint Emilion',
#    'appellation_slug': 'puisseguin-saint-emilion',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': None,
#    'vintage': '2016',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 88.52,
#    'confidence_index': 'C+',
#    'journalist_count': 3,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'Barton & Guestier, Chateau Magnol, Haut Medoc',
#    'wine_id': 9295,
#    'wine_slug': 'barton-guestier-chateau-magnol-haut-medoc',
#    'appellation': 'Haut Medoc',
#    'appellation_slug': 'haut-medoc',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': 'Cru Bourgeois',
#    'vintage': '2016',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 88.48,
#    'confidence_index': 'B+',
#    'journalist_count': 4,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'Chateau De Malleret, Haut Medoc',
#    'wine_id': 34545,
#    'wine_slug': 'chateau-de-malleret-haut-medoc',
#    'appellation': 'Haut Medoc',
#    'appellation_slug': 'haut-medoc',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': 'Cru Bourgeois',
#    'vintage': '2016',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 88.22,
#    'confidence_index': 'B+',
#    'journalist_count': 7,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'Compagnie Vinicole Edmond De Rothschild, Chateau Des Laurets, Puisseguin Saint Emilion',
#    'wine_id': 35124,
#    'wine_slug': 'compagnie-vinicole-edmond-de-rothschild-chateau-des-laurets-puisseguin-saint-emilion',
#    'appellation': 'Puisseguin Saint Emilion',
#    'appellation_slug': 'puisseguin-saint-emilion',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': None,
#    'vintage': '2016',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 88.06,
#    'confidence_index': 'B+',
#    'journalist_count': 6,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'Chateau Marjosse, Bordeaux',
#    'wine_id': 39086,
#    'wine_slug': 'chateau-marjosse-bordeaux',
#    'appellation': 'Bordeaux',
#    'appellation_slug': 'bordeaux',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': None,
#    'vintage': '2016',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 87.66,
#    'confidence_index': 'A',
#    'journalist_count': 11,
#    'lwin': None,
#    'lwin_11': None},
#   {'wine': 'Chateau Blaignan, Medoc',
#    'wine_id': 32660,
#    'wine_slug': 'chateau-blaignan-medoc',
#    'appellation': 'Medoc',
#    'appellation_slug': 'medoc',
#    'color': 'Red',
#    'wine_type': '',
#    'regions': ['Bordeaux'],
#    'country': 'France',
#    'classification': 'Cru Bourgeois',
#    'vintage': '2016',
#    'date': '2019-06-15',
#    'is_primeurs': False,
#    'score': 87.47,
#    'confidence_index': 'B+',
#    'journalist_count': 7,
#    'lwin': None,
#    'lwin_11': None}]}
